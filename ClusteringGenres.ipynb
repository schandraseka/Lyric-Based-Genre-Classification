# %%
import numpy as np
import pandas as pd
import nltk
from nltk.stem.snowball import SnowballStemmer
from bs4 import BeautifulSoup
import re
import os
import codecs
from sklearn import feature_extraction
from gensim.models import Word2Vec
from sklearn.manifold import TSNE
from bokeh.plotting import figure, show
from bokeh.io import push_notebook, output_notebook
from bokeh.models import ColumnDataSource, LabelSet

def tokenize_and_stem(text):
    # first tokenize by sentence, then by word to ensure that punctuation is caught as it's own token
    tokens = [word for sent in nltk.sent_tokenize(text) for word in nltk.word_tokenize(sent)]
    filtered_tokens = []
    # filter out any tokens not containing letters (e.g., numeric tokens, raw punctuation)
    for token in tokens:
        if re.search('[a-zA-Z]', token):
            filtered_tokens.append(token)
    stems = [stemmer.stem(t) for t in filtered_tokens]
    return stems

def interactive_tsne(text_labels, tsne_array):
    '''makes an interactive scatter plot with text labels for each point'''

    # define a dataframe to be used by bokeh context
    bokeh_df = pd.DataFrame(tsne_array, text_labels, columns=['x','y'])
    bokeh_df['text_labels'] = bokeh_df.index

    # interactive controls to include to the plot
    TOOLS="hover, zoom_in, zoom_out, box_zoom, undo, redo, reset, box_select"

    p = figure(tools=TOOLS, plot_width=700, plot_height=700)

    # define data source for the plot
    source = ColumnDataSource(bokeh_df)

    # scatter plot
    p.scatter('x', 'y', source=source, fill_alpha=0.6,
              fill_color="#8724B5",
              line_color=None)

    # text labels
    labels = LabelSet(x='x', y='y', text='text_labels', y_offset=8,
                      text_font_size="6pt", text_color="#555555",
                      source=source, text_align='center')

    p.add_layout(labels)

    # show plot inline
    output_notebook()
    show(p)


data = pd.read_csv('lyrics.csv')
data = data.dropna()
data = data.head(3000)
lyrics_list = []

for ix,row in data.iterrows():
    chars_rm = ['\n',',','[',']','.','?','!','(',')',':']
    ly = row['lyrics']
    for char in ly:
        if char in chars_rm:
            ly = ly.replace(char,' ')
        elif char=='\'':
            ly = ly.replace(char,'')
    lyrics_list.append(ly)
    
data['lyrics'] = lyrics_list

artistsongs = {}
for ix,row in data.iterrows():
    singer = row['artist']
    if singer in artistsongs:
        artistsongs[singer].append(row['lyrics'].split(' '))
    else:
        artistsongs[singer]=[row['lyrics'].split(' ')]

top_artists = ['beyonce-knowles', 'evan-taubenfeld', 'chuckie']
processed_data = pd.DataFrame({'Artist':list(set(data['artist'].tolist())), 'Lyrics Compilation':[artistsongs[artist] for artist in set(data['artist'].tolist())]})
stopwords = nltk.corpus.stopwords.words('english')
stemmer = SnowballStemmer("english")
for artists in top_artists:
    totalvocab_stemmed = []
    totalvocab_tokenized = []
    for song in processed_data[processed_data['Artist'] == artists]['Lyrics Compilation'].tolist()[0]:
        allwords_stemmed = []
        for line in song:
            # for each item in 'synopses', tokenize/stem
            line = re.sub('[!@#$]', '', line)
            allwords_stemmed.extend(tokenize_and_stem(line)) # extend the 'totalvocab_stemmed' list
        totalvocab_stemmed.append(allwords_stemmed)
    model = Word2Vec(sentences=totalvocab_stemmed, # tokenized senteces, list of list of strings
                 size=300,  # size of embedding vectors
                 workers=4, # how many threads?
                 min_count=20, # minimum frequency per token, filtering rare words
                 sample=0.05, # weight of downsampling common words
                 sg = 0, # should we use skip-gram? if 0, then cbow
                 iter=5,
                 hs = 0
        )
    X = model[model.wv.vocab]
    tsne = TSNE(n_components=2)
    X_tsne = tsne.fit_transform(X)
    interactive_tsne(model.wv.vocab.keys(), X_tsne)
# Out:
#     <div class="bk-root">
#         <a href="https://bokeh.pydata.org" target="_blank" class="bk-logo bk-logo-small bk-logo-notebook"></a>
#         <span id="07715f81-fd62-43da-a32a-448b479cb3c1">Loading BokehJS ...</span>
#     </div>
#     <div class="bk-root">
#         <div class="bk-plotdiv" id="f53516ad-882e-4eb1-bc7c-9c0086af9c72"></div>
#     </div>
# <script type="text/javascript">
#
#   (function(root) {
#     function now() {
#       return new Date();
#     }
#
#     var force = false;
#
#     if (typeof (root._bokeh_onload_callbacks) === "undefined" || force === true) {
#       root._bokeh_onload_callbacks = [];
#       root._bokeh_is_loading = undefined;
#     }
#
#
#
#     if (typeof (root._bokeh_timeout) === "undefined" || force === true) {
#       root._bokeh_timeout = Date.now() + 0;
#       root._bokeh_failed_load = false;
#     }
#
#     var NB_LOAD_WARNING = {'data': {'text/html':
#        "<div style='background-color: #fdd'>\n"+
#        "<p>\n"+
#        "BokehJS does not appear to have successfully loaded. If loading BokehJS from CDN, this \n"+
#        "may be due to a slow or bad network connection. Possible fixes:\n"+
#        "</p>\n"+
#        "<ul>\n"+
#        "<li>re-rerun `output_notebook()` to attempt to load from CDN again, or</li>\n"+
#        "<li>use INLINE resources instead, as so:</li>\n"+
#        "</ul>\n"+
#        "<code>\n"+
#        "from bokeh.resources import INLINE\n"+
#        "output_notebook(resources=INLINE)\n"+
#        "</code>\n"+
#        "</div>"}};
#
#     function display_loaded() {
#       if (root.Bokeh !== undefined) {
#         var el = document.getElementById("f53516ad-882e-4eb1-bc7c-9c0086af9c72");
#         if (el != null) {
#           el.textContent = "BokehJS " + Bokeh.version + " successfully loaded.";
#         }
#       } else if (Date.now() < root._bokeh_timeout) {
#         setTimeout(display_loaded, 100)
#       }
#     }
#
#
#     function run_callbacks() {
#       try {
#         root._bokeh_onload_callbacks.forEach(function(callback) { callback() });
#       }
#       finally {
#         delete root._bokeh_onload_callbacks
#       }
#       console.info("Bokeh: all callbacks have finished");
#     }
#
#     function load_libs(js_urls, callback) {
#       root._bokeh_onload_callbacks.push(callback);
#       if (root._bokeh_is_loading > 0) {
#         console.log("Bokeh: BokehJS is being loaded, scheduling callback at", now());
#         return null;
#       }
#       if (js_urls == null || js_urls.length === 0) {
#         run_callbacks();
#         return null;
#       }
#       console.log("Bokeh: BokehJS not loaded, scheduling load and callback at", now());
#       root._bokeh_is_loading = js_urls.length;
#       for (var i = 0; i < js_urls.length; i++) {
#         var url = js_urls[i];
#         var s = document.createElement('script');
#         s.src = url;
#         s.async = false;
#         s.onreadystatechange = s.onload = function() {
#           root._bokeh_is_loading--;
#           if (root._bokeh_is_loading === 0) {
#             console.log("Bokeh: all BokehJS libraries loaded");
#             run_callbacks()
#           }
#         };
#         s.onerror = function() {
#           console.warn("failed to load library " + url);
#         };
#         console.log("Bokeh: injecting script tag for BokehJS library: ", url);
#         document.getElementsByTagName("head")[0].appendChild(s);
#       }
#     };var element = document.getElementById("f53516ad-882e-4eb1-bc7c-9c0086af9c72");
#     if (element == null) {
#       console.log("Bokeh: ERROR: autoload.js configured with elementid 'f53516ad-882e-4eb1-bc7c-9c0086af9c72' but no matching script tag was found. ")
#       return false;
#     }
#
#     var js_urls = [];
#
#     var inline_js = [
#       function(Bokeh) {
#         (function() {
#           var fn = function() {
#             var docs_json = {"c27f7d55-0875-4665-9535-6bec7420bc64":{"roots":{"references":[{"attributes":{"plot":null,"text":""},"id":
"id":"c5ab91ad-9ef8-439d-86fe-81d5c091a4f1","type":"BoxAnnotation"},{"id":"270f31c2-eb5d-4d01-9b08-adcaede3041e","type":"GlyphRenderer"},{"id":"3e809138-4dfc-4e61-bb83-be74501f7300","type":"LabelSet"}],"title":{"id":"25f3aeb6-87db-4fd1-b704-1ac9a46fc263","type":"Title"},"toolbar":{"id":"debeac13-7233-4120-abe9-a6d06f423a20","type":"Toolbar"},"x_range":{"id":"16505d20-2e66-4dff-a028-d6730b9d18e8","type":"DataRange1d"},"x_scale":{"id":"4bc81429-9260-48a4-909e-d0b763691406","type":"LinearScale"},"y_range":{"id":"c35b94a7-5019-4887-a147-475657388d3f","type":"DataRange1d"},"y_scale":{"id":"631a3959-2b4b-4b92-b9d2-c427cae698cf","type":"LinearScale"}},"id":"16eb2b5b-3a7b-4b53-95d5-3bb84354bf54","subtype":"Figure","type":"Plot"},{"attributes":{},"id":"28ec50ab-ee28-472f-be47-90ef7006ab19","type":"BasicTickFormatter"},{"attributes":{},"id":"631a3959-2b4b-4b92-b9d2-c427cae698cf","type":"LinearScale"},{"attributes":{"plot":null,"text":""},"id":"25f3aeb6-87db-4fd1-b704-1ac9a46fc263","type":"Title"},{"attributes":{"callback":null,"column_names":["x","y","text_labels","index"],"data":{"index":["oh","babi","how","you","do","know","im","gon","na","right","to","the","chase","some","were","made","but","me","myself","i","like","think","that","was","for","a","what","more","than","feel","it","on","let","get","lost","dont","need","call","into","work","caus","your","real","want","show","big","whi","well","got","my","heart","aint","id","rather","up","bodi","and","didnt","insid","no","lie","too","wide","strong","wont","much","he","talk","this","can","back","ego","such","love","his","walk","now","leav","with","or","could","have","when","find","damn","kill","them","better","matter","fact","smile","mayb","eye","boy","see","kind","of","someth","so","must","everi","bitch","if","beat","sing","everyth","easi","seem","sure","still","way","not","then","thing","come","our","though","we","ask","as","they","bring","just","tri","realli","say","even","through","day","might","about","word","out","from","all","time","hold","in","ill","listen","tell","is","there","wrong","be","are","will","sleep","same","hear","ive","felt","new","act","go","would","mind","stay","by","hard","live","look","truth","blind","alway","give","chorus","lone","ever","someon","pretti","face","believ","friend","until","end","promis","again","deep","while","gone","where","els","turn","one","vers","stand","life","make","rock","wan","kiss","ya","pleas","touch","night","run","befor","keep","lovin","best","littl","singl","wish","dream","bridg","worth","thank","us","fine","cri","pain","parti","peopl","pop","sit","around","at","start","hook","stop","am","black","ring","saw","d ...

# %%
data
# Out:
#       index                                               song  year  \
# 0         0                                          ego-remix  2009
# 1         1                                       then-tell-me  2009
# 2         2                                            honesty  2009
# 3         3                                    you-are-my-rock  2009
# 4         4                                      black-culture  2009
# 5         5                             all-i-could-do-was-cry  2009
# 6         6                                 once-in-a-lifetime  2009
# 7         7                                            waiting  2009
# 8         8                                          slow-love  2009
# 9         9                              why-don-t-you-love-me  2009
# 10       10                                      save-the-hero  2009
# 11       11                                          telephone  2009
# 12       12                                    ice-cream-truck  2009
# 13       13                             no-broken-hearted-girl  2009
# 14       14                                            control  2009
# 15       15                                      i-m-alone-now  2009
# 16       16                                             poison  2009
# 17       17                                   world-wide-women  2007
# 18       18                                     beautiful-liar  2007
# 19       19                             beautiful-liar-spanish  2007
# 20       20                   beautiful-liar-spanglish-version  2007
# 21       21                                          bienvenue  2007
# 22       22                                beutiful-liar-remix  2007
# 23       23  he-still-loves-me-f-choir-from-fighting-tempta...  2007
# 24       24                                    bello-embustero  2007
# 25       25                                         irreplable  2007
# 26       26                                      the-first-day  2007
# 27       27                                             my-man  2007
# 28       28                                 what-s-it-gonna-be  2007
# 29       29                                                 if  2007
# ...     ...                                                ...   ...
# 4334   4334                                    well-absolutely  2013
# 4337   4337                                          the-first  2012
# 4338   4338                                    jesse-mccartney  2012
# 4342   4342                                            holiday  2011
# 4345   4345                                            you-can  2011
# 4349   4349                                         hikikomori  2016
# 4350   4350                                        bodega-bamz  2014
# 4359   4359                                         the-hunter  2012
# 4393   4393                               lights-camera-action  2014
# 4394   4394                                    sato-tai-paisto  2012
# 4409   4409                                   sorcerer-s-dream  2010
# 4410   4410                                just-you-just-blues  2010
# 4421   4421                                     homeless-child  2016
# 4422   4422                            burn-down-the-cornfield  2016
# 4428   4428                               shootin-for-the-moon  2016
# 4432   4432                                     just-a-feeling  2015
# 4440   4440                                 natural-born-lover  2008
# 4441   4441                                    tennessee-woman  2008
# 4442   4442                                     i-m-a-stranger  2008
# 4443   4443                                         cinderella  2007
# 4444   4444                                 goodbye-i-love-you  2007
# 4445   4445                                             always  2007
# 4446   4446                           just-remember-i-love-you  2006
# 4447   4447                                        even-steven  2006
# 4448   4448                                        sold-on-you  2006
# 4449   4449                                       someday-soon  2006
# 4450   4450                                        only-a-fool  2006
# 4451   4451                                         just-think  2006
# 4452   4452                                            so-long  2006
# 4453   4453                                        strange-way  2006
#
#                    artist    genre  \
# 0         beyonce-knowles      Pop
# 1         beyonce-knowles      Pop
# 2         beyonce-knowles      Pop
# 3         beyonce-knowles      Pop
# 4         beyonce-knowles      Pop
# 5         beyonce-knowles      Pop
# 6         beyonce-knowles      Pop
# 7         beyonce-knowles      Pop
# 8         beyonce-knowles      Pop
# 9         beyonce-knowles      Pop
# 10        beyonce-knowles      Pop
# 11        beyonce-knowles      Pop
# 12        beyonce-knowles      Pop
# 13        beyonce-knowles      Pop
# 14        beyonce-knowles      Pop
# 15        beyonce-knowles      Pop
# 16        beyonce-knowles      Pop
# 17        beyonce-knowles      Pop
# 18        beyonce-knowles      Pop
# 19        beyonce-knowles      Pop
# 20        beyonce-knowles      Pop
# 21        beyonce-knowles      Pop
# 22        beyonce-knowles      Pop
# 23        beyonce-knowles      Pop
# 24        beyonce-knowles      Pop
# 25        beyonce-knowles      Pop
# 26        beyonce-knowles      Pop
# 27        beyonce-knowles      Pop
# 28        beyonce-knowles      Pop
# 29        beyonce-knowles      Pop
# ...                   ...      ...
# 4334        body-language      Pop
# 4337        body-language      Pop
# 4338        body-language      Pop
# 4342        body-language      Pop
# 4345        body-language      Pop
# 4349        forneverworld    Other
# 4350               el-rey    Other
# 4359         esprit-d-air     Rock
# 4428  Waitin there by the side of the River Waitin t...
# 4432  Just a feelin Feelin I had on my mind Just a f...
# 4440  Ive been on the prowl in my Clipper Deluxe Dri...
# 4441  Got a pretty woman  lives way down in Tennesse...
# 4442  Some people ask me  what does a stranger  stra...
# 4443  Last December I met a girl She took a likin to...
# 4444  Maybe you think Im letting you go Maybe its no...
# 4445  Howve you been  say its me again Its been a lo...
# 4446  When it all goes crazy and the thrill is gone ...
# 4447  Stevie  dont you let her go Dont you have the ...
# 4448  Well its the things I do Its the way I see Ain...
# 4449  Someday soon---were gonna quit this crazy runa...
# 4450  In a moment of madness I let you say goodbye Y...
# 4451  What if everything was different Never the sam...
# 4452  Nevermind the reason  you may never know Blame...
# 4453  Didnt I hear you cry this mornin didnt I feel ...
#
# [3000 rows x 6 columns]

# %%
genresongs = {}
for ix,row in data.iterrows():
    genre = row['genre']
    if genre in genresongs:
        genresongs[genre].append(row['lyrics'].split(' '))
    else:
        genresongs[genre]=[row['lyrics'].split(' ')]
        
top_genres = ['Rock', 'Hip-Hop', 'Pop']
genre_processed_data = pd.DataFrame({'Genre':list(set(data['genre'].tolist())), 'Lyrics Compilation':[genresongs[genre] for genre in set(data['genre'].tolist())]})
dic = {}
for genres in top_genres:
    totalvocab_stemmed = []
    totalvocab_tokenized = []
    for song in genre_processed_data[genre_processed_data['Genre'] == genres]['Lyrics Compilation'].tolist()[0]:
        allwords_stemmed = []
        for line in song:
            # for each item in 'synopses', tokenize/stem
            line = re.sub('[!@#$]', '', line)
            allwords_stemmed.extend(tokenize_and_stem(line)) # extend the 'totalvocab_stemmed' list
        totalvocab_stemmed.append(allwords_stemmed)
    model = Word2Vec(sentences=totalvocab_stemmed, # tokenized senteces, list of list of strings
                 size=300,  # size of embedding vectors
                 workers=4, # how many threads?
                 min_count=20, # minimum frequency per token, filtering rare words
                 sample=0.05, # weight of downsampling common words
                 sg = 0, # should we use skip-gram? if 0, then cbow
                 iter=5,
                 hs = 0
        )
    X = model[model.wv.vocab]
    tsne = TSNE(n_components=2)
    X_tsne = tsne.fit_transform(X)
    dic[genres] = ((model.wv.vocab.keys(), X_tsne))
    #interactive_tsne(model.wv.vocab.keys(), X_tsne)

bokeh_df = pd.DataFrame(dic['Hip-Hop'][1], dic['Hip-Hop'][0], columns=['x','y'])
bokeh_df['text_labels'] = bokeh_df.index

    # interactive controls to include to the plot
TOOLS="hover, zoom_in, zoom_out, box_zoom, undo, redo, reset, box_select"

p = figure(tools=TOOLS, plot_width=700, plot_height=700)

# define data source for the plot
source = ColumnDataSource(bokeh_df)

# scatter plot
t = p.scatter('x', 'y', source=source, fill_alpha=0.6,
              fill_color="#8724B5",
              line_color=None)

# text labels
labels = LabelSet(x='x', y='y', text='text_labels', y_offset=8,
                      text_font_size="6pt", text_color="#555555",
                      source=source, text_align='center')

p.add_layout(labels)

# show plot inline
output_notebook()
show(p)    

def update(genre):
    if genre == 'Pop':
        bokeh_df = pd.DataFrame(dic['Pop'][1], dic['Pop'][0], columns=['x','y'])
        bokeh_df['text_labels'] = bokeh_df.index
        source = ColumnDataSource(bokeh_df)
        t.data_source.data = source.data
    elif genre == 'Rock':
        bokeh_df = pd.DataFrame(dic['Rock'][1], dic['Rock'][0], columns=['x','y'])
        bokeh_df['text_labels'] = bokeh_df.index
        source = ColumnDataSource(bokeh_df)
        t.data_source.data = source.data
    else:
        bokeh_df = pd.DataFrame(dic['Hip-Hop'][1], dic['Hip-Hop'][0], columns=['x','y'])
        bokeh_df['text_labels'] = bokeh_df.index
        source = ColumnDataSource(bokeh_df)
        t.data_source.data = source.data
    output_notebook()
    show(p)
    
interact(update, genre = ['Rock', 'Hip-Hop', 'Pop'])
# Out:
#     <div class="bk-root">
#         <a href="https://bokeh.pydata.org" target="_blank" class="bk-logo bk-logo-small bk-logo-notebook"></a>
#         <span id="d3082067-57b1-47b2-9176-3b9534e14f50">Loading BokehJS ...</span>
#     </div>
#     <div class="bk-root">
#         <div class="bk-plotdiv" id="5ff2f0c8-e6e3-45e8-8035-a943f921f5a5"></div>
#     </div>
# <script type="text/javascript">
#
#   (function(root) {
#     function now() {
#       return new Date();
#     }
#
#     var force = false;
#
#     if (typeof (root._bokeh_onload_callbacks) === "undefined" || force === true) {
#       root._bokeh_onload_callbacks = [];
#       root._bokeh_is_loading = undefined;
#     }
#
#
#
#     if (typeof (root._bokeh_timeout) === "undefined" || force === true) {
#       root._bokeh_timeout = Date.now() + 0;
#       root._bokeh_failed_load = false;
#     }
#
#     var NB_LOAD_WARNING = {'data': {'text/html':
#        "<div style='background-color: #fdd'>\n"+
#        "<p>\n"+
#        "BokehJS does not appear to have successfully loaded. If loading BokehJS from CDN, this \n"+
#        "may be due to a slow or bad network connection. Possible fixes:\n"+
#        "</p>\n"+
#        "<ul>\n"+
#        "<li>re-rerun `output_notebook()` to attempt to load from CDN again, or</li>\n"+
#        "<li>use INLINE resources instead, as so:</li>\n"+
#        "</ul>\n"+
#        "<code>\n"+
#        "from bokeh.resources import INLINE\n"+
#        "output_notebook(resources=INLINE)\n"+
#        "</code>\n"+
#        "</div>"}};
#
#     function display_loaded() {
#       if (root.Bokeh !== undefined) {
#         var el = document.getElementById("5ff2f0c8-e6e3-45e8-8035-a943f921f5a5");
#         if (el != null) {
#           el.textContent = "BokehJS " + Bokeh.version + " successfully loaded.";
#         }
#       } else if (Date.now() < root._bokeh_timeout) {
#         setTimeout(display_loaded, 100)
#       }
#     }
#
#
#     function run_callbacks() {
#       try {
#         root._bokeh_onload_callbacks.forEach(function(callback) { callback() });
#       }
#       finally {
#         delete root._bokeh_onload_callbacks
#       }
#       console.info("Bokeh: all callbacks have finished");
#     }
#
#     function load_libs(js_urls, callback) {
#       root._bokeh_onload_callbacks.push(callback);
#       if (root._bokeh_is_loading > 0) {
#         console.log("Bokeh: BokehJS is being loaded, scheduling callback at", now());
#         return null;
#       }
#       if (js_urls == null || js_urls.length === 0) {
#         run_callbacks();
#         return null;
#       }
#       console.log("Bokeh: BokehJS not loaded, scheduling load and callback at", now());
#       root._bokeh_is_loading = js_urls.length;
#       for (var i = 0; i < js_urls.length; i++) {
#         var url = js_urls[i];
#         var s = document.createElement('script');
#         s.src = url;
#         s.async = false;
#         s.onreadystatechange = s.onload = function() {
#           root._bokeh_is_loading--;
#           if (root._bokeh_is_loading === 0) {
#             console.log("Bokeh: all BokehJS libraries loaded");
#             run_callbacks()
#           }
#         };
#         s.onerror = function() {
#           console.warn("failed to load library " + url);
#         };
#         console.log("Bokeh: injecting script tag for BokehJS library: ", url);
#         document.getElementsByTagName("head")[0].appendChild(s);
#       }
#     };var element = document.getElementById("5ff2f0c8-e6e3-45e8-8035-a943f921f5a5");
#     if (element == null) {
#       console.log("Bokeh: ERROR: autoload.js configured with elementid '5ff2f0c8-e6e3-45e8-8035-a943f921f5a5' but no matching script tag was found. ")
#       return false;
#     }
#
#     var js_urls = [];
#
#     var inline_js = [
#       function(Bokeh) {
#         (function() {
#           var fn = function() {
#             var docs_json = {"dd0ace0f-0db1-4bbc-a2fe-60291f0a9ad8":{"roots":{"references":[{"attributes":{"plot":{"id":"81567007-c166-46ea-b488-22cc465cf33f","subtype":"Figure","type":"Plot"},"ticker":{"id":"5c16b390-da7e-4f10-87db-5b8b29b32d36","type":"BasicTicker"}},"id":"9ad92b2f-653c-4a2f-8d08-31170b3eff31","type":"Grid"},{"attributes":{"callback":null,"column_names":["x","y","text_labels","index"],"data":{"index":["chorus","when","you","hit","me","on","my","know","what","want","call","alreadi","the","low","im","sayin","hey","i","got","that","ta","and","playin","corner","it","about","vers","eazi","tell","bout","a","nigga","name","e","hittin","in","compton","work","gettin","they","stop","but","so","say","with","come","power","mine","by","hour","man","fuck","ima","get","while","good","boyz","da","hood","of","muthafucka","see","he","aint","us","street","we","just","do","for","buck","trust","move","from","back","bus","to","life","still","this","homi","who","lock","down","doin","not","em","time","cant","ya","did","feel","like","now","everybodi","till","day","die","uh","huh","well","known","them","game","up","wan","na","him","throw","yo","side","ill","onli","mr","if","talkin","then","kid","thinkin","gone","an","ride","let","fli","five","bad","yea","is","stupid","dont","realli","shoot","dead","nothin","enough","dope","fast","money","car","some","drink","be","funki","eazy-","your","ball","bass","show","shit","rap","dick","boy","quit","rock","motherfuck","around","way","mean","roll","through","find","kick","polic","have","hook","right","turn","go","past","myself","can","kiss","ass","hip","drunk","lip","put","old","had","cold","east","big","word","took","look","at","face","bitch","was","hoe","tip","hold","light","fit","flip","his","off","floor","bottl","went","store","as","punk","insid","came","out","gat","fire","all","becaus","rollin","es","plan","take","or","yes","too","step","parti","hell","three","said","breath","hand","lot","ho","ask","her","danc","she","no","tryin","keep","cool","homeboy","walk","start","dog","watch","dumb","full","make","sick","over","drop","8-ball","pass","tear","yall","listen","close","place","dre","beat","write","rhyme","crazi","d","pump","muthaphukkin","hop","shout","these","fake","ha","caus","babi","g","dogg","niggaz","better","act","somebodi","rememb","wasnt","gon","yeah","whi","minut","bust","quick","thought","soon","befor","begin","mother","friend","damn","blind","young","pad","gang","sign","hous","grab","point","fool","jump","front","play","bumpin","new","gangsta","top","own","somethin","there","pull","fresh","kilo","window","makin","cuz","n","tha","are","alway","hard","trash","card","knowin","legit","quot","give","til","caught","littl","one","la","spot","where","chill","left","girl","bodi","someth","made","mad","couldnt","believ","wouldnt","pimp","slap","knock","under","control","oh","brother","buy","anoth","home","cop","dark","green","head","guess","cut","crime","two","straight","year","didnt","gave","shot","hurt","both","murder","were","shes","pussi","here","song","smoke","real","love","id","rather","night","mouth","knew","would","how","bring","nut","pain","need","other","check","eat","think","master","weed","high","today","eye","red","mama","pick","wit","leav","away","lookin","blow","fuckin","pack","comin","even","told","laid","readi","must","everi","yet","hear","case","may","givin","first","youll","trick","broke","shake","break","rich","without","goe","wont","care","burn","x2","lose","might","use","stori","imma","their","paid","muthafuckin","sinc","fall","much","lick","toe","last","save","free","pay","deal","pleas","touch","suck","onc","those","everyth","talk","cap","higher","than","live","gun","ren","sure","fact","should","map","aliv","yella","club","buddi","will","stick","runnin","run","part","town","kind","more","alright","bet","mic","gs","whole","tri","pop","never","heard","twist","o","peopl","wrong","crew","flow","els","ground","everyday","world","least","heart","wonder","funk","mind","our ...
# <function __main__.update>

# %%
from ipywidgets import interact
def updates(genre):
    if genre == 'Hip-Hop':
        bokeh_df = pd.DataFrame(dic['Hip-Hop'][1], dic['Hip-Hop'][0], columns=['x','y'])
        bokeh_df['text_labels'] = bokeh_df.index
        source = ColumnDataSource(bokeh_df)
        t.data_source.data = source.data
    elif genre == 'Rock':
        bokeh_df = pd.DataFrame(dic['Rock'][1], dic['Rock'][0], columns=['x','y'])
        bokeh_df['text_labels'] = bokeh_df.index
        source = ColumnDataSource(bokeh_df)
        t.data_source.data = source.data
    else:
        bokeh_df = pd.DataFrame(dic['Pop'][1], dic['Pop'][0], columns=['x','y'])
        bokeh_df['text_labels'] = bokeh_df.index
        source = ColumnDataSource(bokeh_df)
        t.data_source.data = source.data
    output_notebook()
    show(p)
interact(updates, genre = ['Rock', 'Hip-Hop', 'Pop'])
# Out:
# <function __main__.updates>

# %%
data['artist'].iloc[1280:3000]
# Out:
# 1846       dreadful-shadows
# 1847       dreadful-shadows
# 1848       dreadful-shadows
# 1849       dreadful-shadows
# 1850       dreadful-shadows
# 1851       dreadful-shadows
# 1852       dreadful-shadows
# 1853       dreadful-shadows
# 1854       dreadful-shadows
# 1855       dreadful-shadows
# 1856       dreadful-shadows
# 1857       dreadful-shadows
# 1858       dreadful-shadows
# 1859       dreadful-shadows
# 1860       dreadful-shadows
# 1861       dreadful-shadows
# 1862       dreadful-shadows
# 1863       dreadful-shadows
# 1864       dreadful-shadows
# 1865       dreadful-shadows
# 1866       dreadful-shadows
# 1867       dreadful-shadows
# 1868       dreadful-shadows
# 1869       dreadful-shadows
# 1870       dreadful-shadows
# 1871       dreadful-shadows
# 1872       dreadful-shadows
# 1873       dreadful-shadows
# 1874       dreadful-shadows
# 1875       dreadful-shadows
#                ...
# 4334          body-language
# 4337          body-language
# 4338          body-language
# 4342          body-language
# 4345          body-language
# 4349          forneverworld
# 4350                 el-rey
# 4359           esprit-d-air
# 4393              georgie-b
# 4394           fintelligens
# 4409    charlie-musselwhite
# 4410    charlie-musselwhite
# 4421    charlie-musselwhite
# 4422    charlie-musselwhite
# 4428    charlie-musselwhite
# 4432    charlie-musselwhite
# 4440    charlie-musselwhite
# 4441    charlie-musselwhite
# 4442    charlie-musselwhite
# 4443               firefall
# 4444               firefall
# 4445               firefall
# 4446               firefall
# 4447               firefall
# 4448               firefall
# 4449               firefall
# 4450               firefall
# 4451               firefall
# 4452               firefall
# 4453               firefall
# Name: artist, Length: 1720, dtype: object
